# %%
import PIL
import glob
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
base_dir = "./data/severstal-steel-defect-detection/"
csv_path = os.path.join(base_dir, "train.csv")

df = pd.read_csv(csv_path)

# %%
PIL.Image.open(os.path.join(base_dir,"train_images", df["ImageId"][0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x256 at 0x1A191A610>

# %%
nunique = df["ClassId"].value_counts()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(nunique.index, nunique)
plt.show()

# %%
df["PixelLoc"] = df["EncodedPixels"].apply(lambda x: list(map(int, x.split(' '))))
df.drop(["EncodedPixels"], axis=1, inplace=True)

# %%
train_images = glob.glob(os.path.join(base_dir, "train_images/*"))
test_images = glob.glob(os.path.join(base_dir, "test_images/*"))

# %%
total_train = len(train_images)
total_test = len(test_images)

# %%
total_defects = len(df['ImageId'])
no_defects = total_train - total_defects

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.pie([total_defects, no_defects], (0.1, 0), ["defects", "no defects"], colors=['lightpink', 'green'], autopct='%1.2f%%', shadow=True, startangle=90, radius=1.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('#333', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-8ab5e7cc9cdf> in <module>
#       1 fig = plt.figure()
#       2 ax = fig.add_axes([0,0,1,1])
# ----> 3 ax.pie([total_defects, no_defects], (0.1, 0), ["defects", "no defects"], colors=['lightpink', '#333'], autopct='%1.2f%%', shadow=True, startangle=90, radius=1.5)
#       4 plt.show()
#
# /usr/local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2852                                360. * max(theta1, theta2),
#    2853                                facecolor=get_next_color(),
# -> 2854                                **wedgeprops)
#    2855             slices.append(w)
#    2856             self.add_patch(w)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in __init__(self, center, r, theta1, theta2, width, **kwargs)
#    1034         %(Patch)s
#    1035         """
# -> 1036         Patch.__init__(self, **kwargs)
#    1037         self.center = center
#    1038         self.r, self.width = r, width
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      78         else:
#      79             self.set_edgecolor(edgecolor)
# ---> 80             self.set_facecolor(facecolor)
#      81         # unscaled dashes.  Needed to scale dash patterns by lw
#      82         self._us_dashes = None
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in set_facecolor(self, color)
#     299         """
#     300         self._original_facecolor = color
# --> 301         self._set_facecolor(color)
#     302
#     303     def set_color(self, c):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in _set_facecolor(self, color)
#     287             color = mpl.rcParams['patch.facecolor']
#     288         alpha = self._alpha if self._fill else 0
# --> 289         self._facecolor = colors.to_rgba(color, alpha)
#     290         self.stale = True
#     291
#
# /usr/local/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 176         rgba = _to_rgba_no_colorcycle(c, alpha)
#     177         try:
#     178             _colors_full_map.cache[c, alpha] = rgba
#
# /usr/local/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     218         except ValueError:
#     219             pass
# --> 220         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     221     # tuple color.
#     222     c = np.array(c)
#
# ValueError: Invalid RGBA argument: '#333'
