# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib.rc
# Out:
# UsageError: Line magic function `%matplotlib.rc` not found.

# %%
image = tf.io.read_file("./data/cats_and_dogs_filtered/train/cats/cat.1.jpg")

# %%
image = tf.image.decode_jpeg(image)

# %%
gray_image = tf.image.rgb_to_grayscale(image)
gray_re_image = tf.reshape(
    gray_image, (280, 300), name=None
)

# %%
plt.imshow(np.reshape(gray_image.numpy(), (280, 300)), cmap='gray', vmin=0, vmax=255)

# %%
img = tf.random.normal(shape=(16,96,96,1),dtype=tf.float32) # replace with your image data

grad_components = tf.image.sobel_edges(img)

grad_mag_components = grad_components**2

grad_mag_square = tf.math.reduce_sum(grad_mag_components,axis=-1) # sum all magnitude components

grad_mag_img = tf.sqrt(grad_mag_square)

# %%
plt.imshow(np.reshape(grad_mag_img[0].numpy(), (96, 96)), cmap='gray')

# %%
grad_mag_img.shape
# Out:
# TensorShape([16, 96, 96, 1])
